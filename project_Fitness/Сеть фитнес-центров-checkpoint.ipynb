# %% [markdown]
# # Разработка стратегии взаимодействия с пользователями на основе аналитических данных сети фитнес-центров «Культурист-датасаентист»

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Задача
#
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что пользователь больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество анкет пользователей. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.

# %% [markdown]
# ### Оглавление
# 1. [Загрузим данные](#start)
# 2. [Исследовательский анализ данных (EDA)](#Часть_1)
# 3. [Модель прогнозирования оттока пользователей](#Часть_2)
# 4. [Кластеризация пользователей](#Часть_3)
# 5. [Выводы и рекомендации по работе с клиентами](#tail)

# %% [markdown]
# ## Шаг 1. Загрузим данные <a id="start"> </a>

# %%
# Загрузим библитеки
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

# %%
# Читаем данные
gym_churn = pd.read_csv('/datasets/gym_churn.csv')

# %%
# Посморим первые 5 строк
gym_churn.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
# Округлим значения признаков до 1 знака после запятой
gym_churn = gym_churn.round(1)
gym_churn.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                          14.2                    5.0
# 1             1   31                         113.2                   12.0
# 2             0   28                         129.4                    1.0
# 3             1   33                          62.7                   12.0
# 4             0   26                         198.4                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
# общая информация о данных в таблице
gym_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
# gender                               4000 non-null int64
# Near_Location                        4000 non-null int64
# Partner                              4000 non-null int64
# Promo_friends                        4000 non-null int64
# Phone                                4000 non-null int64
# Contract_period                      4000 non-null int64
# Group_visits                         4000 non-null int64
# Age                                  4000 non-null int64
# Avg_additional_charges_total         4000 non-null float64
# Month_to_end_contract                4000 non-null float64
# Lifetime                             4000 non-null int64
# Avg_class_frequency_total            4000 non-null float64
# Avg_class_frequency_current_month    4000 non-null float64
# Churn                                4000 non-null int64
# dtypes: float64(4), int64(10)
# ...

# %% [markdown]
# Текущие поля в датасете:
#
# `Churn` — факт оттока в текущем месяце;
#
# - Данные пользователя за предыдущий до проверки факта оттока месяц:
#
#     `gender` — пол
#
#     `Near_Location` — проживание или работа в районе, где находится фитнес-центр
#
#     `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на    абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента)
#
#     `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента)
#
#     `Phone` — наличие контактного телефона
#
#     `Age` — возраст
#
#     `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах)
#
#
# - Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#
#     `Contract_period` — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
#
#     `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах)
#
#     `Group_visits` — факт посещения групповых занятий
#
#     `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента
#
#     `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц
#
#     `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон

# %%
# Переведем все названия столбцов к нижнему регистру.
gym_churn.columns = gym_churn.columns.str.lower()
gym_churn.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %%
# Проверим наличие дубликатов
gym_churn.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Выводы**

# %% [markdown]
# Загрузили данные, пропусков не обнаружили, все признаки числовые. Привел названия колонок к нижнему регистру и округлил значения признаков (до одного знака после запятой) для удобства.

# %% [markdown]
# ## Шаг 2. Проведите исследовательский анализ данных (EDA) <a id="Часть_1"> </a>

# %% [markdown]
# Посмотрим на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения.

# %%
# Применим метод describe() для получения сводки числовых
gym_churn.describe().T
# Out:
#                                     count        mean        std   min  \
# gender                             4000.0    0.510250   0.499957   0.0
# near_location                      4000.0    0.845250   0.361711   0.0
# partner                            4000.0    0.486750   0.499887   0.0
# promo_friends                      4000.0    0.308500   0.461932   0.0
# phone                              4000.0    0.903500   0.295313   0.0
# contract_period                    4000.0    4.681250   4.549706   1.0
# group_visits                       4000.0    0.412250   0.492301   0.0
# age                                4000.0   29.184250   3.258367  18.0
# avg_additional_charges_total       4000.0  146.943675  96.355200   0.1
# month_to_end_contract              4000.0    4.322750   4.191297   1.0
# lifetime                           4000.0    3.724750   3.749267   0.0
# avg_class_frequency_total          4000.0    1.879575   0.972513   0.0
# ...

# %% [markdown]
# Отток клиентов составляет 26%, 84% проживают или работа в районе, где находится фитнес-центр. 48% клиентов являются сотрудниками компаний-партнёров клуба, 30% использовали промо-код от знакомого при оплате первого абонемента.

# %% [markdown]
# Посмотрим средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался.

# %%
# Средние значения признаков для тех, кто остался - 0 и тех, кто ушел - 1 
gym_churn.groupby('churn').mean().T
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445934  115.082092
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.025247    1.476060
# avg_class_frequency_current_month    2.027492    1.043450

# %% [markdown]
# Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).

# %%
# Построим гистограммы признаков для тех, кто ушёл (gone) и тех, кто остался (left)
left = gym_churn.query('churn == 0')
gone = gym_churn.query('churn == 1')

for feature in gym_churn.columns:
    left[feature].hist(bins=20, alpha=0.5, figsize=(7,5), label='left')
    gone[feature].hist(bins=20, alpha=0.5, figsize=(7,5), label='gone')
    plt.legend()
    plt.title('Распределение пользователей по признаку {}'.format(feature))
    plt.xlabel('Пользователи: gone - ушли, left - остались')
    plt.ylabel('Количество пользователей')
    plt.show()

# %% [markdown]
# Постройте матрицу корреляций и отобразите её.

# %%
# Построим матрицу корреляций
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(gym_churn.corr(), xticklabels=gym_churn.corr().columns, 
            yticklabels=gym_churn.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('Матрица корреляций', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Сильная связь между Contract_period и Month_to_end_contract. Средняя корреляция между Partner и Promo_friends, возможно сотрудник компании-партнёра клуба позвал с собой в фитнес-центр друга по акции «приведи друга».
#
# Обратная связь прослеживается между Churn и Lifetime (клиенты, которые перестали ходить в первый месяц),
# Avg_class_frequency_current_month, Age, Contract_period (клиенты, переставшие ходить склоны заключать договор на короткий срок).

# %% [markdown]
# **Выводы**

# %% [markdown]
# Изучили данные, выяснили, что 76% ушедших проживают или работа в районе, где находится фитнес-центр. 1/3 клиентов - сотрудники компании-партнёра клуба, а 1/5 пришли в рамках акции «приведи друга». Клиенты, которые попали в отток в большинстве случаев оформляли договор сроком от 1 до 3 месяцев и посещали клуб 1-2 раза в неделю.

# %% [markdown]
# ## Шаг 3. Постройте модель прогнозирования оттока пользователей <a id="Часть_2"> </a>

# %% [markdown]
# Постройте модель бинарной классификации пользователей, где целевой признак — факт оттока пользователя в следующем месяце:

# %% [markdown]
# Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
#
# Обучите модель на train-выборке двумя способами:
# - логистической регрессией
# - случайным лесом
#
# Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
# Не забудьте указать параметр random_state при разделении выборки и задании алгоритма.

# %%
# разделим наши данные на признаки (матрица X) и целевую переменную (y)
X = gym_churn.drop('churn', axis = 1)
y = gym_churn['churn']

# разделим модель на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# выбираем алгоритм для модели
model = LogisticRegression(random_state=42)
# обучаем модель
model.fit(X_train,y_train)
# бинарный прогноз
predictions = model.predict(X_test)
# воспользуемся моделью, чтобы сделать прогнозы
probabilities = model.predict_proba(X_test)[:, 1]

print('Метрики для логистической регрессией:')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, predictions)))
print()

# зададим алгоритм для новой модели на основе алгоритма случайного леса
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 42)
# обучим модель случайного леса
rf_model.fit(X_train, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
rf_predictions = rf_model.predict(X_test)
rf_probabilities = rf_model.predict_proba(X_test)[:,1]

print('Метрики для случайного леса:')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, rf_predictions)))
# Out:
# Метрики для логистической регрессией:
# Accuracy: 0.92
# Precision: 0.86
# Recall: 0.82
# F1: 0.84
#
# Метрики для случайного леса:
# Accuracy: 0.92
# Precision: 0.85
# Recall: 0.81
# F1: 0.83

# %% [markdown]
# **Выводы**

# %% [markdown]
# Мы построили модель логистической регрессией и случайного леса.
# Модель логистической регрессией показала себя немного лучше на основании метрик: Precision, Recall, F1.
# Accuracy - доля правильных ответов одинакова для двух моделей.

# %% [markdown]
# ## Шаг 4. Сделайте кластеризацию пользователей <a id="Часть_3"> </a>

# %% [markdown]
# Отложим в сторону столбец с оттоком и проведём кластеризацию объектов (пользователей):
#
# - Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму.

# %%
# Отложим в сторону столбец с оттоком
X = gym_churn.drop('churn', axis = 1)

# Cтандартизируем данные
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# Построим матрицу расстояний
linked = linkage(X_sc, method = 'ward')

# Нарисуем дендрограмму
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# На основании полученного графика, можно выделить 4 кластера.

# %% [markdown]
# - Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов. За число кластеров применим n=4, на основании графика из предыдущего пункта.

# %%
# задаём число кластеров, равное 5
km = KMeans(random_state=42, n_clusters = 5) 

# применяем алгоритм к данным и формируем вектор кластеров
labels = km.fit_predict(X_sc)

# сохраняем метки кластера в поле нашего датасета
gym_churn['cluster_km'] = labels

# %% [markdown]
# Посмотрим на средние значения признаков для кластеров.

# %%
# выводим статистику по средним значениям наших признаков по кластеру
gym_churn.groupby('cluster_km').mean().T
# Out:
# cluster_km                                  0           1           2  \
# gender                               0.500000    0.508718    0.477193
# near_location                        0.000000    0.954872    1.000000
# partner                              0.463602    0.747692    0.915789
# promo_friends                        0.078544    0.514872    0.595322
# phone                                1.000000    1.000000    1.000000
# contract_period                      2.362069   11.200000    2.598830
# group_visits                         0.216475    0.551795    0.374269
# age                                 28.578544   30.028718   28.828070
# avg_additional_charges_total       136.782567  165.490256  137.425146
# month_to_end_contract                2.216475   10.191795    2.424561
# lifetime                             2.909962    4.849231    3.467836
# avg_class_frequency_total            1.739080    2.170769    1.627719
# ...

# %% [markdown]
# Построим распределения признаков для кластеров.

# %%
# Построим графикрафик распределения признаков для кластеров
cluster_0 = gym_churn.query('cluster_km == 0') 
cluster_1 = gym_churn.query('cluster_km == 1')
cluster_2 = gym_churn.query('cluster_km == 2')
cluster_3 = gym_churn.query('cluster_km == 3')
cluster_4 = gym_churn.query('cluster_km == 4')

for feature in gym_churn.columns:
    cluster_0[feature].hist(bins=25, alpha=0.5, figsize=(7,5), label='cluster_0')
    cluster_1[feature].hist(bins=25, alpha=0.5, figsize=(7,5), label='cluster_1')
    cluster_2[feature].hist(bins=25, alpha=0.5, figsize=(7,5), label='cluster_2')
    cluster_3[feature].hist(bins=25, alpha=0.5, figsize=(7,5), label='cluster_3')
    cluster_4[feature].hist(bins=25, alpha=0.5, figsize=(7,5), label='cluster_4')
    plt.legend()
    plt.title('График распределения {} по кластерам'.format(feature))
    plt.xlabel('Кластер')
    plt.ylabel('Количество пользователей')
    plt.show()

# %% [markdown]
# Портреты пользователей для кластеров:
#
# Кластер № 0
#
# Отличительная черта пользователей, что они не проживают и не работают в районе, где находится фитнес-центр.
#
# Кластер № 1
#
# Как правило оформляют договор сроком на 1 год, в среднем приносят самую высокую выручку, часто и регулярно посещают занятия.
#
# Кластер № 2
#
# В основном это сотрудники компании-партнёра клуба и их друзья, купившие абонемент в рамках акции «приведи друга».
#
# Кластер № 3
#
# Нет в наличии контактного телефона.
#
# Кластер № 4
#
# Пользователи, которые купили абонемент не в рамках проводимых акций ("сотрудник компании-партнёра клуба", "приведи друга").

# %% [markdown]
# Для каждого полученного кластера посчитаем долю оттока.

# %%
# Доля оттока для каждого полученного кластера
gym_churn.groupby('cluster_km').agg(churn_mean = ('churn', 'mean')).sort_values('churn_mean', ascending=False)
# Out:
#             churn_mean
# cluster_km
# 0             0.429119
# 4             0.355784
# 2             0.312281
# 3             0.266839
# 1             0.018462

# %% [markdown]
# ## Шаг 5. Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами <a id="tail"> </a>

# %% [markdown]
# Мы проанализировали данные пользователей сети фитнес-центров «Культурист-датасаентист». Выяснили, что 85% живут или работают возле клубов, 53% - являются сотрудниками компаний-партнеров клуба. Зафиксирован факт оттока 26% пользователей. Построили модель бинарной классификации пользователей (логистическая регрессия и случайный лес). Доля правильных ответов одинакова для двух моделей 92%, но точность у логистической регрессии лучше - 86%.
# Далее мы нарисовали дендрограмму, на основании полученного графика можно выделить 4 кластера. Обучив модель кластеризации на основании алгоритма K-Means, сделали кластеризацию пользователей.
#
# Рекомендации:
#
# Пользователям, у которых срок договора подходит к концу необходимо сделать смс рассылку, менеджерам по продажам дать выгрузку этих клиентов, пусть звонят перезаключают договора. Так же можно сделать акцию на групповые занятия, клиент может найти там единомышленников, новых друзей. Это может дать мотивацию продолжить ходить в клуб и уменьшит отток.
